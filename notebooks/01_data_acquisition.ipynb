# %% [markdown]
# # 📊 Data Acquisition and Initial Exploration
#
# **Author:** [Ton nom]
#
# **Date:** January 5, 2026
#
# **Objective:** Load the Students Performance dataset and perform initial exploration.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print('✅ Libraries imported successfully!')

# %%
# Load dataset
df = pd.read_csv('../data/StudentsPerformance.csv')

print(f'Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns')

# %%
# Display first 10 rows
df.head(10)

# %%
# Dataset information
print('=== DATASET INFO ===')
df.info()

# %%
# Check for missing values
print('=== MISSING VALUES ===')
print(df.isnull().sum())
print(f'\nTotal missing values: {df.isnull().sum().sum()}')

# %%
# Check for duplicates
print(f'Duplicates: {df.duplicated().sum()}')

# %%
# Descriptive statistics
df.describe()

# %%
# Column names and types
print('=== COLUMNS ===')
print(df.columns.tolist())
print('\n=== DATA TYPES ===')
print(df.dtypes)

# %%
# Summary
print('\n=== DATASET SUMMARY ===')
print(f'Total students: {len(df)}')
print(f'Features: {df.shape[1]}')
print(f'Missing values: {df.isnull().sum().sum()}')
print(f'Duplicates: {df.duplicated().sum()}')
print('\nCategorical variables:')
for col in df.select_dtypes(include='object').columns:
    print(f'  - {col}: {df[col].nunique()} unique values')
print('\nNumerical variables:')
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    print(f'  - {col}: range [{df[col].min()}, {df[col].max()}]')

# %% [markdown]
# ## 📌 Key Findings
#
# - Dataset contains **1000 students** with **8 variables**
# - **No missing values** detected
# - **No duplicates** found
# - **5 categorical features**: gender, race/ethnicity, parental education, lunch, test prep
# - **3 numerical scores**: math, reading, writing (range 0-100)
# - Dataset is clean and ready for analysis
